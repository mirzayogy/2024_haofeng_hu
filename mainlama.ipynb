# %%
import importlib
# import lib.show
import lib.A_acc
# importlib.reload(lib.show)
importlib.reload(lib.A_acc)
from lib.show import show_image_group_view
from lib.A_acc import get_color_corrected, get_color_corrected_increased_dynamic_range


# an_image = "../UIEB/pernah/44_im_increased_.png" # bluish
# an_image = "../UIEB/pernah/121_img_.png" # bluish
# an_image = "../UIEB/pernah/383_img_.png" # greenish
# an_image = "../UIEB/pernah/906_img_.png" # greenish
# an_image = "../UIEB/pernah/202_img_.png" # yellowish
an_image = "../UIEB/pernah/471_img_.png" # yellowish

an_image1 = "../UIEB/raw-890/12324.png" # JADI BIRU
an_image2 = "../UIEB/raw-890/12433.png" # JADI MERAH
an_image3 = "../UIEB/raw-890/15113.png" # JADI MERAH

# show_image_from_path(an_image) # visualize the image and the label
im_increased = get_color_corrected_increased_dynamic_range(an_image, device=None) 

im_pilihan = [
        an_image1,
        an_image2,
        an_image3]

import pandas as pd
image_group = pd.DataFrame({'image': im_pilihan, 'label': im_pilihan, 'validation_type': im_pilihan, 'validation_value': im_pilihan})
image_group


# plt.imshow(im_increased)

# show_image_matplotlib(im_increased)

# if im_increased.ndim == 2:  # grayscale
#     plt.imshow(im_increased, cmap="gray")
# else:  # warna
#     plt.imshow(im_increased)
# plt.axis("off")
# plt.show()
# Out:
#                        image                      label  \
# 0  ../UIEB/raw-890/12324.png  ../UIEB/raw-890/12324.png
# 1  ../UIEB/raw-890/12433.png  ../UIEB/raw-890/12433.png
# 2  ../UIEB/raw-890/15113.png  ../UIEB/raw-890/15113.png
#
#              validation_type           validation_value
# 0  ../UIEB/raw-890/12324.png  ../UIEB/raw-890/12324.png
# 1  ../UIEB/raw-890/12433.png  ../UIEB/raw-890/12433.png
# 2  ../UIEB/raw-890/15113.png  ../UIEB/raw-890/15113.png
